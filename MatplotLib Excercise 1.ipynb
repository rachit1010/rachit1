# %%
from matplotlib import pyplot as plt

# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd
import numpy as np

# %%
sample_data = pd.read_csv('sample_data.csv')
sample_data
# Out:
#    column_a  column_b  column_c
# 0         1         1        10
# 1         2         4         8
# 2         3         9         6
# 3         4        16         4
# 4         5        25         2

# %%
type(sample_data)
# Out:
# pandas.core.frame.DataFrame

# %%
(sample_data.column_c.iloc[3])
# Out:
# 4

# %%
plt.plot(sample_data.column_a,sample_data.column_b,label="For b")
plt.plot(sample_data.column_a,sample_data.column_c,label="For c")
plt.title('Sample Data')
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.legend()
plt.show()

# %%
data = pd.read_csv('countries.csv')
data
# Out:
#           country  year  population
# 0     Afghanistan  1952     8425333
# 1     Afghanistan  1957     9240934
# 2     Afghanistan  1962    10267083
# 3     Afghanistan  1967    11537966
# 4     Afghanistan  1972    13079460
# ...           ...   ...         ...
# 1699     Zimbabwe  1987     9216418
# 1700     Zimbabwe  1992    10704340
# 1701     Zimbabwe  1997    11404948
# 1702     Zimbabwe  2002    11926563
# 1703     Zimbabwe  2007    12311143
#
# [1704 rows x 3 columns]

# %%
data["population"].max()
# Out:
# 1318683096

# %%
data[data.country=='India']
# Out:
#     country  year  population
# 696   India  1952   372000000
# 697   India  1957   409000000
# 698   India  1962   454000000
# 699   India  1967   506000000
# 700   India  1972   567000000
# 701   India  1977   634000000
# 702   India  1982   708000000
# 703   India  1987   788000000
# 704   India  1992   872000000
# 705   India  1997   959000000
# 706   India  2002  1034172547
# 707   India  2007  1110396331

# %%
ind = data[data.country=='India']

# %%
ind
# Out:
#     country  year  population
# 696   India  1952   372000000
# 697   India  1957   409000000
# 698   India  1962   454000000
# 699   India  1967   506000000
# 700   India  1972   567000000
# 701   India  1977   634000000
# 702   India  1982   708000000
# 703   India  1987   788000000
# 704   India  1992   872000000
# 705   India  1997   959000000
# 706   India  2002  1034172547
# 707   India  2007  1110396331

# %%
type(ind)
# Out:
# pandas.core.frame.DataFrame

# %%
chi = data[data.country=="China"]
chi
# Out:
#     country  year  population
# 288   China  1952   556263527
# 289   China  1957   637408000
# 290   China  1962   665770000
# 291   China  1967   754550000
# 292   China  1972   862030000
# 293   China  1977   943455000
# 294   China  1982  1000281000
# 295   China  1987  1084035000
# 296   China  1992  1164970000
# 297   China  1997  1230075000
# 298   China  2002  1280400000
# 299   China  2007  1318683096

# %%
plt.plot(ind.year,ind.population / 10**6,label="India")
plt.plot(chi.year,chi.population / 10**6,label="China")
plt.title("Year Vs Population")
plt.xlabel("Year")
plt.ylabel("Population in Mil")
plt.legend()
plt.show()

# %%
ind.population
# Out:
# 696     372000000
# 697     409000000
# 698     454000000
# 699     506000000
# 700     567000000
# 701     634000000
# 702     708000000
# 703     788000000
# 704     872000000
# 705     959000000
# 706    1034172547
# 707    1110396331
# Name: population, dtype: int64

# %%
ind.population / ind.population.iloc[0] *100
# Out:
# 696    100.000000
# 697    109.946237
# 698    122.043011
# 699    136.021505
# 700    152.419355
# 701    170.430108
# 702    190.322581
# 703    211.827957
# 704    234.408602
# 705    257.795699
# 706    278.003373
# 707    298.493637
# Name: population, dtype: float64

# %%
plt.plot(ind.year,ind.population / ind.population.iloc[0] *100,label="India")
plt.plot(chi.year,chi.population / chi.population.iloc[0] *100,label="China")
plt.style.use("Solarize_Light2")
plt.title("Year Vs Population growth (first year =100%)")
plt.xlabel("Year")
plt.ylabel("Population in Mil")
plt.legend()
plt.show()

# %%
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark', 'seaborn-dark-palette', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'tableau-colorblind10']

# %%
data
# Out:
#           country  year  population
# 0     Afghanistan  1952     8425333
# 1     Afghanistan  1957     9240934
# 2     Afghanistan  1962    10267083
# 3     Afghanistan  1967    11537966
# 4     Afghanistan  1972    13079460
# ...           ...   ...         ...
# 1699     Zimbabwe  1987     9216418
# 1700     Zimbabwe  1992    10704340
# 1701     Zimbabwe  1997    11404948
# 1702     Zimbabwe  2002    11926563
# 1703     Zimbabwe  2007    12311143
#
# [1704 rows x 3 columns]

# %%
data[data["year"]<=1955]
# Out:
#                  country  year  population
# 0            Afghanistan  1952     8425333
# 12               Albania  1952     1282697
# 24               Algeria  1952     9279525
# 36                Angola  1952     4232095
# 48             Argentina  1952    17876956
# ...                  ...   ...         ...
# 1644             Vietnam  1952    26246839
# 1656  West Bank and Gaza  1952     1030585
# 1668         Yemen, Rep.  1952     4963829
# 1680              Zambia  1952     2672000
# 1692            Zimbabwe  1952     3080907
#
# [142 rows x 3 columns]

# %%
g = data.groupby("country")
g

# %%
for country,country_data in g:
    print(country)
    print(country_data)
# Out:
# Afghanistan
#         country  year  population
# 0   Afghanistan  1952     8425333
# 1   Afghanistan  1957     9240934
# 2   Afghanistan  1962    10267083
# 3   Afghanistan  1967    11537966
# 4   Afghanistan  1972    13079460
# 5   Afghanistan  1977    14880372
# 6   Afghanistan  1982    12881816
# 7   Afghanistan  1987    13867957
# 8   Afghanistan  1992    16317921
# 9   Afghanistan  1997    22227415
# 10  Afghanistan  2002    25268405
# 11  Afghanistan  2007    31889923
# Albania
#     country  year  population
# 12  Albania  1952     1282697
# 13  Albania  1957     1476505
# 14  Albania  1962     1728137
# 15  Albania  1967     1984060
# 16  Albania  1972     2263554
# 17  Albania  1977     2509048
# 18  Albania  1982     2780097
# 19  Albania  1987     3075321
# 20  Albania  1992     3326498
# 21  Albania  1997     3428038
# 22  Albania  2002     3508512
# 23  Albania  2007     3600523
# Algeria
#     country  year  population
# 24  Algeria  1952     9279525
# ...

# %%
df = pd.read_csv('cricketworldcup.csv')
df
# Out:
#     Year                       Host       Winner  Score    Runner-up  Score.1
# 0   1975                    England  West Indies    291    Australia      274
# 1   1979                    England  West Indies    286      England      194
# 2   1983                    England        India    183  West Indies      140
# 3   1987         India and Pakistan    Australia    253      England      246
# 4   1992  Australia and New Zealand     Pakistan    249      England      227
# 5   1996         Pakistan and India    Sri Lanka    245    Australia      241
# 6   1999                    England    Australia    133     Pakistan      132
# 7   2003               South Africa    Australia    359        India      234
# 8   2007                West Indies    Australia    281    Sri Lanka      215
# 9   2011       India and Bangladesh        India    277    Sri Lanka      274
# 10  2015  Australia and New Zealand    Australia    186  New Zealand      183
# ...

# %%
df["Winner"].max()
# Out:
# 'West Indies'

# %%
g = df.groupby("Winner")
g

# %%
for Winner,Winner_df in g:
    print(Winner)
    print(Winner_df)
    #df[0]
# Out:
# Australia
#     Year                       Host     Winner  Score    Runner-up  Score.1
# 3   1987         India and Pakistan  Australia    253      England      246
# 6   1999                    England  Australia    133     Pakistan      132
# 7   2003               South Africa  Australia    359        India      234
# 8   2007                West Indies  Australia    281    Sri Lanka      215
# 10  2015  Australia and New Zealand  Australia    186  New Zealand      183
# England
#     Year               Host   Winner  Score    Runner-up  Score.1
# 11  2019  England and Wales  England    241  New Zealand      241
# India
#    Year                  Host Winner  Score    Runner-up  Score.1
# 2  1983               England  India    183  West Indies      140
# 9  2011  India and Bangladesh  India    277    Sri Lanka      274
# Pakistan
#    Year                       Host    Winner  Score Runner-up  Score.1
# 4  1992  Australia and New Zealand  Pakistan    249   England      227
# ...

# %%
  plt.bar(df.year, df.Winner)
    plt.show()
# Out:
#   File "<ipython-input-207-d7dc5d6eda3f>", line 2
#     plt.show()
#     ^
# IndentationError: unexpected indent

# %%
df.count()

# %%
df[['Winner']].count()

# %%
df.Winner.count()

# %%
article_read

# %%
df.head()
# Out:
#    Year                       Host       Winner  Score    Runner-up  Score.1
# 0  1975                    England  West Indies    291    Australia      274
# 1  1979                    England  West Indies    286      England      194
# 2  1983                    England        India    183  West Indies      140
# 3  1987         India and Pakistan    Australia    253      England      246
# 4  1992  Australia and New Zealand     Pakistan    249      England      227

# %%
df1=df.groupby('Winner').count().reset_index()
df1=df1.drop(['Host','Score','Runner-up','Score.1'],axis=1)
print(df1)
plt.bar(df1['Winner'],df1['Year'])
plt.show()
# Out:
#         Winner  Year
# 0    Australia     5
# 1      England     1
# 2        India     2
# 3     Pakistan     1
# 4    Sri Lanka     1
# 5  West Indies     2
